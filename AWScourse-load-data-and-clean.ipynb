# %%
#Data load

from sklearn.datasets import fetch_california_housing
# fetching the dataset
import pandas as pd
dataset = fetch_california_housing()
housing_data = pd.DataFrame(dataset.data)
housing_data.head()
# Out:
#         0     1         2         3       4         5      6       7
# 0  8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1  8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2  7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3  5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4  3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25

# %%
housing_data.shape
#show how many rows (observations = 20640) and columns (features =8)
# Out:
# (20640, 8)

# %%
#Drop features with missing values

from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
from math import sqrt
import random
import numpy as np
random.seed(0)

#fetching from dataset
import pandas as pd
dataset = fetch_california_housing()
train, target = pd.DataFrame(dataset.data), pd.DataFrame(dataset.target)
train.columns = ['zero','one','two','thee','four','five','six','seven']
train.insert(loc=len(train.columns), column='target', value=target)

#Randomly replace 40% of the first column with NaN values
column = train['zero']
missing_pct = int(column.size * 0.4)
i = [random.choice(range(column.shape[0])) for _ in range (missing_pct)]
column[i] = np.NaN
train
# Out:
#          zero   one       two      thee    four      five    six   seven  \
# 0         NaN  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2         NaN  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4         NaN  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...       ...   ...       ...       ...     ...       ...    ...     ...
# 20635  1.5603  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  2.5568  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.7000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638     NaN  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639  2.3886  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
#        target
# 0       4.526
# 1       3.585
# 2       3.521
# 3       3.413
# ...

# %%
train.shape
# Out:
# (20640, 9)

# %%
###############################################
#Remove observations with missing values
#Will drop all raws that have missing values
##############################################
train.dropna(inplace=True)
train.shape
# Out:
# (13783, 9)

# %%
train
# Out:
#          zero   one       two      thee    four      five    six   seven  \
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 5      4.0368  52.0  4.761658  1.103627   413.0  2.139896  37.85 -122.25
# 6      3.6591  52.0  4.931907  0.951362  1094.0  2.128405  37.84 -122.25
# 9      3.6912  52.0  4.970588  0.990196  1551.0  2.172269  37.84 -122.25
# ...       ...   ...       ...       ...     ...       ...    ...     ...
# 20633  2.5495  27.0  5.445026  1.078534  1082.0  2.832461  39.19 -121.53
# 20635  1.5603  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  2.5568  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.7000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20639  2.3886  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
#        target
# 1       3.585
# 3       3.413
# 5       2.697
# 6       2.992
# ...
